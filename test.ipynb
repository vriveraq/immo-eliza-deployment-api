# %%
import pandas as pd
from  data_preprocessing import preprocessing_new_data

test= {
  "locality_name": "Leuven",
  "postal_code": 7180  ,
  "type_of_property": "House",
  "subtype_of_property": "House",
  "number_of_rooms": 3,
  "living_area": 250,
  "equipped_kitchen": 0,
  "furnished": 0,
  "open_fire": 0,
  "terrace": 0,
  "garden": 0,
  "number_of_facades": 0,
  "swimming_pool": 0,
  "state_of_building": "Normal",
  "garden_surface": 0,
  "terrace_surface": 0
}

clean_data = pd.read_csv("./clean_data.csv")

print(preprocessing_new_data(clean_data,pd.DataFrame([test])))
# Out:
#      postal_code  province_encoded  region_encoded
# 0           7180          0.114599        0.444088
# 1           7090          0.114599        0.444088
# 2           7100          0.114599        0.444088
# 3           6560          0.114599        0.444088
# 4           7000          0.114599        0.444088
# ...          ...               ...             ...
# 6845        1070          0.073139        0.073139
# 6846        1030          0.073139        0.073139
# 6847        1180          0.073139        0.073139
# 6848        1060          0.073139        0.073139
# 6849        1190          0.073139        0.073139
#
# [6850 rows x 3 columns]
#    number_of_rooms  living_area  equipped_kitchen  furnished  open_fire  \
# 0                3          250                 0          0          0
#
#    terrace  garden  number_of_facades  swimming_pool  garden_surface  ...  \
# 0        0       0                  0              0               0  ...
#
#    state_of_building_New  state_of_building_Normal  \
# 0                    0.0                       1.0
#
#    state_of_building_To demolish  state_of_building_To renovate  \
# 0                            0.0                            0.0
#
#    state_of_building_To restore  state_of_building_Under construction  \
# 0                           0.0                                   0.0
#
#    state_of_building_Unknown  postal_encoded  province_encoded  region_encoded
# 0                        0.0        328000.0               NaN             NaN
#
# [1 rows x 40 columns]

# %%
from joblib import load
feature_names = load("./model_features.joblib") #load the feature names used during training
print(feature_names)
# Out:
# ['number_of_rooms', 'living_area', 'equipped_kitchen', 'furnished', 'open_fire', 'terrace', 'garden', 'number_of_facades', 'swimming_pool', 'garden_surface', 'terrace_surface', 'type_of_property_Appartment', 'type_of_property_House', 'subtype_of_property_Bungalow', 'subtype_of_property_Chalet', 'subtype_of_property_Cottage', 'subtype_of_property_Duplex', 'subtype_of_property_Flat', 'subtype_of_property_FlatStudio', 'subtype_of_property_GroundFloor', 'subtype_of_property_House', 'subtype_of_property_Loft', 'subtype_of_property_Mansion', 'subtype_of_property_MasterHouse', 'subtype_of_property_MixedBuilding', 'subtype_of_property_Penthouse', 'subtype_of_property_Triplex', 'subtype_of_property_Villa', 'state_of_building_Excellent', 'state_of_building_Fully renovated', 'state_of_building_New', 'state_of_building_Normal', 'state_of_building_To demolish', 'state_of_building_To renovate', 'state_of_building_To restore', 'state_of_building_Under construction', 'state_of_building_Unknown', 'postal_encoded', 'province_encoded', 'region_encoded']
